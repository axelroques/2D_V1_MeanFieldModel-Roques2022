# %%
# %load_ext autoreload

from v1_mfm import Model

# %% [markdown]
# # Sheet Model

# %%
# %autoreload

sheet_model = Model(
    network='SHEET',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
    custom_network_parameters={},
    custom_stimulation_parameters={},
    build_conn_matrices=True
)
# Out:
# Successfully loaded connectivity matrices.

# %%
# %autoreload
results = sheet_model.run()
# Out:
# Computing... [##################################################] 100.0%
# Simulation completed.

# %%
# %autoreload
sheet_model.save(path='results/')
# Out:
# Simulation saved in results/2022_10_17-22h37min.npy.

# %%
# %autoreload
sheet_model.plot()

# %%
# %autoreload
sheet_model.movie(fps=10, path='results/movies/', title='sheet_model_test')
# Out:
# Movie saved in results/movies/sheet_model_test.mp4.

# %% [markdown]
# # Torus Model

# %%
# %autoreload

torus_model = Model(
    network='TORUS',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
    custom_network_parameters={},
    custom_stimulation_parameters={},
    build_conn_matrices=True
)
# Out:
# Successfully loaded connectivity matrices.

# %%
# %autoreload
results = torus_model.run()
# Out:
# Computing... [##################################################] 100.0%
# Simulation completed.

# %%
# %autoreload
torus_model.save(path='results/')
# Out:
# Simulation saved in results/2022_10_17-22h55min.npy.

# %%
# %autoreload
torus_model.plot()

# %%
# %autoreload
torus_model.movie(fps=10, title='torus_model_test')
# Out:
# Movie saved in results/movies/torus_model_test.mp4.

# %% [markdown]
# # Torus with Random Connections Model

# %%
# %autoreload

torus_random_model = Model(
    network='TORUSRANDOM',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
    custom_network_parameters={},
    custom_stimulation_parameters={},
    random_conn_parameters={
        'nb_random_conn': 90,
        'weight_rand': 1
    },
    build_conn_matrices=True
)
# Out:
# Successfully loaded connectivity matrices.

# %%
# %autoreload
results = torus_random_model.run()
# Out:
# Computing... [##################################################] 100.0%
# Simulation completed.

# %%
# %autoreload
torus_random_model.save(path='results/')
# Out:
# Simulation saved in results/2022_10_17-23h13min.npy.

# %%
# %autoreload
torus_random_model.plot()

# %%
# %autoreload
torus_random_model.movie(fps=10, title='torus_random_model_test')
# Out:
# Movie saved in results/movies/torus_random_model_test.mp4.

# %% [markdown]
# # Load Simulation Results

# %%
model = Model(
    network='TORUS',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
)
model.load(file=f'results/{your_file_here}.npy')
# Out:
# Successfully loaded connectivity matrices.
