# %%
# %load_ext autoreload

from v1_mfm import Model

# %% [markdown]
# # Sheet Model

# %%
# %autoreload

sheet_model = Model(
    network='SHEET',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
)

# %%
# %autoreload
results = sheet_model.run()
# Out:
# ---- Computing time t = 0.0 ms out of 800 ms
# ---- Computing time t = 50.0 ms out of 800 ms
# ---- Computing time t = 100.0 ms out of 800 ms
# ---- Computing time t = 150.0 ms out of 800 ms
# ---- Computing time t = 200.0 ms out of 800 ms
# ---- Computing time t = 250.0 ms out of 800 ms
# ---- Computing time t = 300.0 ms out of 800 ms
# ---- Computing time t = 350.0 ms out of 800 ms
# ---- Computing time t = 400.0 ms out of 800 ms
# ---- Computing time t = 450.0 ms out of 800 ms
# ---- Computing time t = 500.0 ms out of 800 ms
# ---- Computing time t = 550.0 ms out of 800 ms
# ---- Computing time t = 600.0 ms out of 800 ms
# ---- Computing time t = 650.0 ms out of 800 ms
# ---- Computing time t = 700.0 ms out of 800 ms
# ---- Computing time t = 750.0 ms out of 800 ms
# Simulation finished

# %%
# %autoreload
sheet_model.save()

# %%
# %autoreload
sheet_model.plot()

# %%
# %autoreload
sheet_model.movie(fps=10, title='sheet_model_test')
# Out:
# Movie saved in C:\Users\roque\Documents\PythonScripts\MeanFieldModel\v1_mfm\utils\../results/movies/sheet_model_test.mp4.

# %% [markdown]
# # Torus Model

# %%
# %autoreload

model = Model(
    network='TORUS',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
)

# %% [markdown]
# # Torus with Random Connections Model

# %%
# %autoreload

model = Model(
    network='TORUSRANDOM',
    simulation_length=0.8,
    stimulation_type='CENTER',
    BIN=5e-3,
    random_conn_params={
        'nb_random_conn': 90,
        'weight_rand': 1
    }
)
